# %% [markdown]
# ## Importing libraries used for this project

# %%
pip install contractions
# Out:
# Requirement already satisfied: contractions in /usr/local/lib/python3.7/dist-packages (0.1.72)
# Requirement already satisfied: textsearch>=0.0.21 in /usr/local/lib/python3.7/dist-packages (from contractions) (0.0.21)
# Requirement already satisfied: anyascii in /usr/local/lib/python3.7/dist-packages (from textsearch>=0.0.21->contractions) (0.3.1)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.7/dist-packages (from textsearch>=0.0.21->contractions) (1.4.4)

# %%
pip install emoji --upgrade
# Out:
# Requirement already satisfied: emoji in /usr/local/lib/python3.7/dist-packages (1.7.0)

# %%
import numpy as np
import pandas as pd
from google.colab import drive 
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import re #regex package
import contractions

# %% [markdown]
# ## Importing our Review file in csv format. Studying its content

# %%
#moungting to Google Drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#reading DataFrame under csv format
df=pd.read_csv('gdrive/My Drive/Colab Notebooks/Sequence/reviews.csv')

df.shape
# Out:
# (12495, 12)

# %%
df.sample(10)
# Out:
#                                                reviewId  \
# 4666  gp:AOqpTOHKr37K5JHJ8tCIFhg7Aqb7ncmAncAd2FWtkAK...
# 5230  gp:AOqpTOGduKuZ5UsJZq9ztERlmksao1DW6KkFLNBMTub...
# 3898  gp:AOqpTOGfOwIzchWDV7jspiLA56d675RzzcOt7eyzZ4I...
# 7390  gp:AOqpTOF-9ylQzL0DQypp_AT3VRtZ5Hxb5ewIvwHcTj6...
# 1915  gp:AOqpTOEqg5yNK0ckikUcZngddbX5-MkgN-SvvHyPx5P...
# 6527  gp:AOqpTOGASwfU916Z7ABvAu2ZexfFEWp_26-hn-S1izs...
# 4106  gp:AOqpTOHSv-HNnnAS3JoLTr--L9GhyPm7MOKwPSatrQF...
# 8436  gp:AOqpTOHFBxO_rWNUoIUWUroqIWyuhkhLvFt3MG3poQH...
# 4130  gp:AOqpTOF6m19_4zNtZaMxAmLXl_Hzi0wFJbQIMGsbQDa...
# 9557  gp:AOqpTOExfP6ukhYx5ha807aMsFzRWSYAr4JV4Yw0Jz1...
#
#                    userName  \
# 4666            Sarah Yaker
# 5230  Jorge Jedidiah Preble
# 3898                Hasti A
# 7390               Poly Pay
# 1915            David Ešner
# 6527        Manjari Debnath
# 4106          Fátima Condey
# 8436            Shaukat Ali
# 4130          Tundra Dragon
# 9557      Radhika Chaudhary
#
#                                               userImage  \
# 4666  https://play-lh.googleusercontent.com/a-/AOh14...
# 5230  https://play-lh.googleusercontent.com/a-/AOh14...
# 3898  https://play-lh.googleusercontent.com/-0Iq7J4a...
# 7390  https://play-lh.googleusercontent.com/-oSC8zW_...
# 1915  https://play-lh.googleusercontent.com/a-/AOh14...
# 6527  https://play-lh.googleusercontent.com/a-/AOh14...
# 4106  https://play-lh.googleusercontent.com/a-/AOh14...
# 8436  https://play-lh.googleusercontent.com/a-/AOh14...
# 4130  https://play-lh.googleusercontent.com/a-/AOh14...
# 9557  https://play-lh.googleusercontent.com/-JAFX747...
#
#                                                 content  score  thumbsUpCount  \
# 4666  It's nice to have an app that keeps me off my ...      5              0
# 5230  Navigation needs work: you can only navigate w...      3              0
# 3898  It doesn't work for me. It always get out of t...      1              0
# 7390  Simple to use and works great so far! Just wis...      4              0
# 1915  Often freezing and crashing when I wanna add p...      1              1
# 6527  This is a very good app... just if the shoppin...      4              0
# 4106  What motivated me to keep using the app was co...      2             11
# 8436                                          Beautiful      4              0
# 4130  I was super excited to use this app, as it was...      2              0
# 9557                 Nice application for students also      5              0
#
#      reviewCreatedVersion                   at  \
# 4666                  NaN  2020-10-24 03:39:29
# 5230               1.5.11  2020-01-30 05:18:08
# 3898                  NaN  2020-10-10 00:15:56
# 7390             2.28.169  2020-10-21 21:33:50
# 1915                5.8.3  2020-10-03 15:16:44
# 6527                1.2.3  2020-04-19 00:52:36
# 4106               4.22.0  2020-09-08 12:33:28
# 8436               5.13.2  2019-12-19 15:30:28
# 4130                  NaN  2020-08-27 22:18:58
# 9557                  3.0  2020-08-26 11:01:38
#
#                                            replyContent            repliedAt  \
# 4666                                                NaN                  NaN
# 5230                                                NaN                  NaN
# 3898  Hi, please update the app to the latest versio...  2020-10-11 20:24:23
# 7390                                                NaN                  NaN
# 1915                                                NaN                  NaN
# 6527                                                NaN                  NaN
# 4106  Hello, we have made changes to the relevant me...  2020-09-08 16:02:42
# 8436                                                NaN                  NaN
# 4130  Hi,\nSorry for the inconvenience. As independe...  2020-08-30 17:27:23
# 9557                                                NaN                  NaN
#
#      sortOrder                          appId
# 4666    newest                   cc.forestapp
# 5230    newest         com.oristats.habitbull
# 3898    newest                   cc.forestapp
# 7390    newest            com.microsoft.todos
# 1915    newest              com.ticktick.task
# 6527    newest                   com.habitnow
# 4106    newest                   cc.forestapp
# 8436    newest              prox.lab.calclock
# 4130    newest                   cc.forestapp
# 9557    newest  com.gmail.jmartindev.timetune

# %%
#printing number of reviews
print('Total number of Google App Review: {}'.format(len(df)))
# Out:
# Total number of Google App Review: 12495

# %%
#checking a review at a certain order number
review_number = 4300
review = df.iloc[review_number]
print ('Review: {}'.format(review['content']))
print('Tweet score: {}'.format(review['score']))
# Out:
# Review: App molto comoda e semplice. Peccato che dopo l'ultimo aggiornamento gli acquisti possibili senza la versione pro sono diventati veramente pochi, rendendo l'uso dell'app poco stimolante.
# Tweet score: 3

# %%
#visualisation of the % of score for each score type
score_representation = df['score'].value_counts()
plt.pie(score_representation, labels = score_representation.index, autopct = '%1.1ff%%')
plt.show()

# %%
#representation in numbers of each score type using histagram
sns.countplot(df.score)
plt.xlabel('score')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'score')

# %%
df.isnull().sum()
# Out:
# reviewId                   0
# userName                   0
# userImage                  0
# content                    0
# score                      0
# thumbsUpCount              0
# reviewCreatedVersion    2162
# at                         0
# replyContent            6677
# repliedAt               6677
# sortOrder                  0
# appId                      0
# dtype: int64

# %%
# visualisation of most common words with the positive review, with score higher or equal to 4
high_score = df[df['score']>=4]
text = ' '.join(score.lower() for score in high_score['content'])
wordcloud = WordCloud().generate(text)
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
# visualisation of most common words with the neutral review, with score equal to 3
neutral_score = df[df['score']==3]
text = ' '.join(score.lower() for score in neutral_score['content'])
wordcloud = WordCloud().generate(text)
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
# visualisation of most common words with the negative review, with score equal or lower than 2
negative_score = df[df['score']<=2]
text = ' '.join(score.lower() for score in negative_score['content'])
wordcloud = WordCloud().generate(text)
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Text normalisation to reduce randomness in the text.
# We will be removing or replacing items do not add any informational vlaue

# %% [markdown]
# https://regexr.com/

# %%
#instaling emojis in order for our review text normalization

# %%
# replace a character with space
def replace_content(content, replace_content=''):
  content = re.sub('', replace_content, content) #creates substring of the string
  return content

# %%
# transform from emoji to a string
def demojize_content(content):
  content = emoji.demojize(content)
  return content

# %%
# replace a character with space
def replace_content(content, replace_content=''):
  content = re.sub('', replace_content, content) #creates substring of the string
  return content

# %%
# remove hashtag
def remove_hashtag(content, replace_hastage=''):
  content = re.sub('#+', replace_hastage, content) #creates substring of the string
  return content

# %% [markdown]
# ## Text cleaning

# %%
#removing capitalization
def to_lowercase(content):
  content = content.lower()
  return content

# %%
#removing letter repetition
def repetition_removed (content):
  content = re.sub(r'(.)\1+', r'\1\1', content)
  return content

# %%
#removing punctuation repetition
def repetition_punctuation (content, replace_content =''):
  content = re.sub(r'[\?\.\!]+(?=[\?\.\!])',replace_content, content)
  return content

# %%
#working word contractions

# %%
def remove_contractions (content):
  for k, v in contractions.contractions_dict.items():
    content = content.replace(k,v)

# %% [markdown]
# ## Tokenization
